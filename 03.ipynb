# %%
import pandas as pd

# %% [markdown]
# Loading  datas

# %%
coffee_df= pd.read_csv('./warmup-data/coffee.csv')

# %%
coffee_df.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee_df.tail()
# Out:
#          Day Coffee Type  Units Sold
# 9     Friday       Latte          35
# 10  Saturday    Espresso          45
# 11  Saturday       Latte          35
# 12    Sunday    Espresso          45
# 13    Sunday       Latte          35

# %%
coffee_df.size
# Out:
# 42

# %%
coffee_df.shape
# Out:
# (14, 3)

# %%
coffee_df.nunique()
# Out:
# Day            7
# Coffee Type    2
# Units Sold     7
# dtype: int64

# %%
#accessing random data
coffee_df.sample(10)
#changes the sample data,everytime we refersh, or ctr+enter
# Out:
#           Day Coffee Type  Units Sold
# 5   Wednesday       Latte          25
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 1      Monday       Latte          15
# 13     Sunday       Latte          35
# 10   Saturday    Espresso          45
# 0      Monday    Espresso          25
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 2     Tuesday    Espresso          30

# %%
#accessing random data
coffee_df.sample(10,random_state=1)
#provies one sample of data, cannot change
#deterministic
# Out:
#           Day Coffee Type  Units Sold
# 3     Tuesday       Latte          20
# 7    Thursday       Latte          30
# 6    Thursday    Espresso          40
# 2     Tuesday    Espresso          30
# 10   Saturday    Espresso          45
# 4   Wednesday    Espresso          35
# 1      Monday       Latte          15
# 12     Sunday    Espresso          45
# 0      Monday    Espresso          25
# 13     Sunday       Latte          35

# %%
#accessing specific values ,using loc and iloc function

# %%
coffee_df = pd.read_csv('./warmup-data/coffee.csv')

# %%
coffee_df
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee_df.loc[0]
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
coffee_df.loc[[0,1,2,3]] #gives 0,1,2,3th  rows
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30
# 3  Tuesday       Latte          20

# %%
coffee_df.loc[0:3] #accessing using slicing syntax
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30
# 3  Tuesday       Latte          20

# %%
coffee_df.loc[0:]
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee_df.loc[5:12]
# Out:
#           Day Coffee Type  Units Sold
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45

# %%
coffee_df.loc[5:8, "Day"] #gives the days from row 5-8
#we can pass only the  rows,  or both rows and columns
# Out:
# 5    Wednesday
# 6     Thursday
# 7     Thursday
# 8       Friday
# Name: Day, dtype: object

# %%
coffee_df.loc[5:8,["Day","Units Sold"]]
# Out:
#          Day  Units Sold
# 5  Wednesday          25
# 6   Thursday          40
# 7   Thursday          30
# 8     Friday          45

# %%
coffee_df.loc[:,["Coffee Type","Units Sold"]]
# Out:
#    Coffee Type  Units Sold
# 0     Espresso          25
# 1        Latte          15
# 2     Espresso          30
# 3        Latte          20
# 4     Espresso          35
# 5        Latte          25
# 6     Espresso          40
# 7        Latte          30
# 8     Espresso          45
# 9        Latte          35
# 10    Espresso          45
# 11       Latte          35
# 12    Espresso          45
# 13       Latte          35

# %% [markdown]
# accesing data using iloc

# %%
coffee_df = pd.read_csv('./warmup-data/coffee.csv')

# %%
coffee_df
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee_df.iloc[0]
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
coffee_df.iloc[[0,1,2,3]]
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30
# 3  Tuesday       Latte          20

# %%
coffee_df.iloc[0:5]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee_df.iloc[5:8,1] #instead of passing the column  names, we pass the column index.
# Out:
# 5       Latte
# 6    Espresso
# 7       Latte
# Name: Coffee Type, dtype: object

# %%
coffee_df.iloc[5:10,[1,2]]
# Out:
#   Coffee Type  Units Sold
# 5       Latte          25
# 6    Espresso          40
# 7       Latte          30
# 8    Espresso          45
# 9       Latte          35

# %%
coffee_df.loc[1,"Units Sold"] =10 #sets the value of unit sold  at row 1 to 10

# %%
coffee_df.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          10
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %% [markdown]
# #more optimize way to get values,  using  'at' and 'iat'

# %%
coffee_df.at[0,"Units Sold"]
# Out:
# 25

# %%
#at and iat ,we can grab  specific item, cant pass multiple values.

# %%
#cant do this,cant pass multiple values 
#coffee_df.at[0:3,"Units Sold"]

# %%
#same thing  using integer while using iat,cant pass multiple values
#coffee_df.iat[0:3,0]
